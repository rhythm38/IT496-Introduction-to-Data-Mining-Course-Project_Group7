# %%
#importing required datasets
import pandas as pd

# %%
url = 'https://stats.espncricinfo.com/ci/engine/stats/index.html?class=2;filter=advanced;orderby=start;page=5;size=200;spanmin2=01+Jan+2015;spanval2=span;team=1;team=15;team=2;team=25;team=3;team=40;team=5;team=6;team=7;team=8;template=results;type=aggregate;view=results'

# %%
all_table = pd.read_html(url)

# %%
all_table[2]
# Out:
#          Winner Result      Margin     BR  Unnamed: 4  \
# 0      Pakistan    won    102 runs    NaN         NaN
# 1   New Zealand    won     47 runs    NaN         NaN
# 2           NaN    n/r           -    NaN         NaN
# 3    Bangladesh    won   3 wickets    3.0         NaN
# 4    Bangladesh    won      5 runs    NaN         NaN
# 5   Afghanistan    won   6 wickets   19.0         NaN
# 6     Sri Lanka    won    132 runs    NaN         NaN
# 7     Sri Lanka    won   9 wickets  204.0         NaN
# 8     Sri Lanka    won    175 runs    NaN         NaN
# 9      Zimbabwe    won   6 wickets   55.0         NaN
# 10  Netherlands    won   5 wickets   40.0         NaN
# 11    Sri Lanka    won  10 wickets  210.0         NaN
# 12  Netherlands    won   7 wickets  137.0         NaN
# 13    Sri Lanka    won    133 runs    NaN         NaN
# 14          NaN   tied           -    NaN         NaN
# 15    Sri Lanka    won     82 runs    NaN         NaN
# 16    Sri Lanka    won     21 runs    NaN         NaN
# 17    Sri Lanka    won   9 wickets  101.0         NaN
# 18  Netherlands    won     74 runs    NaN         NaN
# 19  Afghanistan    won     17 runs    NaN         NaN
# 20  Netherlands    won   4 wickets   43.0         NaN
# 21    Sri Lanka    won   8 wickets   34.0         NaN
# 22  Afghanistan    won    142 runs    NaN         NaN
# 23    Sri Lanka    won    128 runs    NaN         NaN
# 24   Bangladesh    won   7 wickets  159.0         NaN
# 25        India    won   5 wickets  163.0         NaN
# 26  West Indies    won   6 wickets   80.0         NaN
# 27        India    won    200 runs    NaN         NaN
#
#                         Match      Ground   Start Date  Unnamed: 8
# 0      Pakistan v New Zealand     Karachi   5 May 2023         NaN
# 1      Pakistan v New Zealand     Karachi   7 May 2023         NaN
# 2        Bangladesh v Ireland  Chelmsford   9 May 2023         NaN
# 3        Bangladesh v Ireland  Chelmsford  12 May 2023         NaN
# 4        Bangladesh v Ireland  Chelmsford  14 May 2023         NaN
# 5     Sri Lanka v Afghanistan  Hambantota   2 Jun 2023         NaN
# 6     Sri Lanka v Afghanistan  Hambantota   4 Jun 2023         NaN
# 7     Sri Lanka v Afghanistan  Hambantota   7 Jun 2023         NaN
# 8          Sri Lanka v U.A.E.    Bulawayo  19 Jun 2023         NaN
# 9      Zimbabwe v Netherlands      Harare  20 Jun 2023         NaN
# 10       Netherlands v U.S.A.      Harare  22 Jun 2023         NaN
# 11           Oman v Sri Lanka    Bulawayo  23 Jun 2023         NaN
# 12        Nepal v Netherlands      Harare  24 Jun 2023         NaN
# 13        Ireland v Sri Lanka    Bulawayo  25 Jun 2023         NaN
# 14  Netherlands v West Indies      Harare  26 Jun 2023         NaN
# 15       Scotland v Sri Lanka    Bulawayo  27 Jun 2023         NaN
# 16    Netherlands v Sri Lanka    Bulawayo  30 Jun 2023         NaN
# 17       Zimbabwe v Sri Lanka    Bulawayo   2 Jul 2023         NaN
# 18         Netherlands v Oman      Harare   3 Jul 2023         NaN
# 19   Bangladesh v Afghanistan  Chattogram   5 Jul 2023         NaN
# 20     Netherlands v Scotland    Bulawayo   6 Jul 2023         NaN
# 21    Sri Lanka v West Indies      Harare   7 Jul 2023         NaN
# 22   Bangladesh v Afghanistan  Chattogram   8 Jul 2023         NaN
# 23    Netherlands v Sri Lanka      Harare   9 Jul 2023         NaN
# 24   Bangladesh v Afghanistan  Chattogram  11 Jul 2023         NaN
# 25        West Indies v India  Bridgetown  27 Jul 2023         NaN
# 26        West Indies v India  Bridgetown  29 Jul 2023         NaN
# 27        West Indies v India     Tarouba   1 Aug 2023         NaN

# %%
df =all_table[2]

# %%
df.head()
# Out:
#         Winner Result     Margin   BR  Unnamed: 4                   Match  \
# 0     Pakistan    won   102 runs  NaN         NaN  Pakistan v New Zealand
# 1  New Zealand    won    47 runs  NaN         NaN  Pakistan v New Zealand
# 2          NaN    n/r          -  NaN         NaN    Bangladesh v Ireland
# 3   Bangladesh    won  3 wickets  3.0         NaN    Bangladesh v Ireland
# 4   Bangladesh    won     5 runs  NaN         NaN    Bangladesh v Ireland
#
#        Ground   Start Date  Unnamed: 8
# 0     Karachi   5 May 2023         NaN
# 1     Karachi   7 May 2023         NaN
# 2  Chelmsford   9 May 2023         NaN
# 3  Chelmsford  12 May 2023         NaN
# 4  Chelmsford  14 May 2023         NaN

# %%
df.to_csv('Results5.csv')
